# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("C:/Users/Pablo/Desktop/datasets/sueño_calidad_de_vida.csv")

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200           None
# 1           125/80          75        10000           None
# 2           125/80          75        10000           None
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
df.shape
# Out:
# (374, 13)

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
df.head(5)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# 1         125/80          75        10000           None
# 2         125/80          75        10000           None
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %%
df.tail(5)
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369          68         7000    Sleep Apnea
# 370          68         7000    Sleep Apnea
# 371          68         7000    Sleep Apnea
# 372          68         7000    Sleep Apnea
# 373          68         7000    Sleep Apnea

# %%
df.sample(5)
# Out:
#      Person ID  Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 194        195    Male   43  Salesperson             6.5                 6
# 223        224    Male   44  Salesperson             6.4                 6
# 367        368  Female   59        Nurse             8.0                 9
# 271        272  Female   49        Nurse             6.1                 6
# 139        140    Male   38       Lawyer             7.1                 8
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 194                       45             7   Overweight         130/85
# 223                       45             7   Overweight         130/85
# 367                       75             3   Overweight         140/95
# 271                       90             8   Overweight         140/95
# 139                       60             5       Normal         130/85
#
#      Heart Rate  Daily Steps Sleep Disorder
# 194          72         6000       Insomnia
# 223          72         6000       Insomnia
# 367          68         7000    Sleep Apnea
# 271          75        10000    Sleep Apnea
# 139          68         8000           None

# %%
#medidas de tendencia central 
##age
df=pd.DataFrame(df, columns=["Age"])

#media
media=df["Age"].mean()
print("El promedio de edad es:", media) 

#mediana
mediana=df["Age"].median()
print("La mediana de edad es:", mediana)

#moda
moda=df["Age"].mode()
print("La moda de edad es:", moda)
# Out:
# El promedio de edad es: 42.18449197860963
# La mediana de edad es: 43.0
# La moda de edad es: 0    43
# Name: Age, dtype: int64

# %%
##sleep duration
df=pd.DataFrame(df, columns=["Sleep Duration"])

#media

media=df["Sleep Duration"].mean()
print("El promedio de la duracion del sueño es:", media)

#mediana
mediana=df["Sleep Duration"].median()
print("La mediana de la duracion del sueño es:", mediana)

#moda
moda=df["Sleep Duration"].mode()
print("La moda de la duracion del sueño es:", moda)
# Out:
# El promedio de la duracion del sueño es: nan
# La mediana de la duracion del sueño es: nan
# La moda de la duracion del sueño es: Series([], Name: Sleep Duration, dtype: float64)
# C:\Users\Pablo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
#quality of sleep 
df=pd.DataFrame(df, columns=["Quality of sleep"])

#media
media=df["Quality of sleep"].mean()
print("El promedio de la calidad del sueño es:", media) 

#mediana
mediana=df["Quality of sleep"].median()
print("La mediana de la calidad del sueño es:", mediana)

#moda
moda=df["Quality of sleep"].mode()
print("La moda de la calidad del sueño es:", moda)
# Out:
# El promedio de la calidad del sueño es: nan
# La mediana de la calidad del sueño es: nan
# La moda de la calidad del sueño es: Series([], Name: Quality of sleep, dtype: float64)
# C:\Users\Pablo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
